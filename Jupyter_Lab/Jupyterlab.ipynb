# %% [markdown]
# ## Table of Contents
#
# * [My Holidays](#myholidays)
#     * [Purpose](#purpose)
#     * [Wo Am I?](#whoami)
#     * [Holiday Destination](#holidaydestination)
#         * [Gathering Information](#gatheringinformation)
#         * [Top 3 Activities](#top3activities)
#         * [Embeded Video](#embededvideo)

# %% [markdown]
# # My Holidays <a class="anchor" id="myholidays"></a>

# %% [markdown]
# ## Purpose <a class="anchor" id="purpose"></a>

# %% [markdown]
# The purpose of this nootebooks is to introduce myself and my holidays preferences
#
# <font color=red>Let's Start!<font>

# %% [markdown]
# ## Who Am I? <a class="anchor" id="whoami"></a>

# %%
# Function name asks the user the name of the person

def name(): 
    
    name = input("Please introduce the person:")
    
    print(f'Hello I want to introduce you to {name.capitalize()}')
    print("Here is a picture of him!")

# %%
name()
# Out:
# Please introduce the person:Kike
# Hello I want to Introduce you to Kike

# %% [markdown]
# ![IMG_20210826_172503_1.png](attachment:IMG_20210826_172503_1.png)

# %%
name()
# Out:
# Please introduce the person:
# ''

# %% [markdown]
# ## Holiday Destination <a class="anchor" id="holidaydestination"></a>

# %% [markdown]
# ### Gathering Information <a class="anchor" id="gatheringinginformation"></a>

# %%
# Function destination asks the user his holiday preferences

# %%
def destination():
    
    d1 = input("Do you want to go to the mountain or to the beach?:")
    d2 = input("Do you want to go to a resort?:")
    
    return d1,d2

# %%
destination()
# Out:
# Do you want to go to the mountain or to the beach?:
# Do you want to go to a resort?:
# ('', '')

# %% [markdown]
# ![download.jfif](attachment:download.jfif)

# %%
from IPython.display import Image

filename = "images/Cuba.jpg"

Image(filename)

# %% [markdown]
# ### Top 3 Activities <a class="anchor" id="top3activities"></a>

# %%
from IPython.display import HTML
import IPython.display

# %% [markdown]
# + **Drinking Mojitos**
# + *Lay on the beach*
# + Scuba Diving
# + <span style="color:blue">some *blue* text</span>

# %% [markdown]
# ### Embeded Video <a class="anchor" id="embededvideo"></a>

# %%
# To embed a Youtube video

# %%
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/24yGe2EUgfE?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>')
# Out:
# C:\Users\user\miniconda3\envs\DA_ENV\lib\site-packages\IPython\core\display.py:724: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/24yGe2EUgfE?rel=0&amp;controls=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>

# %%
player = IPython.display.IFrame(src="https://www.youtube.com/embed/s4ABpbxIPFI",
                width="640",
                height="320",
                frameborder="0",
                allowtransparency="true",
                allow="encrypted-media",
                )

# %%
IPython.display.display(player)
# Out:
#         <iframe
#             width="640"
#             height="320"
#             src="https://www.youtube.com/embed/s4ABpbxIPFI?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
