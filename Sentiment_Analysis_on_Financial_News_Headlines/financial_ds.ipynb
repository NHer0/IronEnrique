# %% [markdown]
# # Importing Modules

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
import os
import shutil
from sklearn.model_selection import train_test_split
pd.set_option("display.max_rows", 100)

# %% [markdown]
# # Functions

# %%
def rearrange_columns(df, dict = None):

    if dict is None:

        text = df["text"]
        sentiment = df["sentiment"]

    else:

        text = df[dict["text"]]
        sentiment = df[dict["sentiment"]]

    df = pd.concat([text, sentiment], axis=1)

    return df

# %%
def human_supervision(df, start, end):

    for row in range(start,end):

        text = df["text"][row]
        print(text)
        print("---------")
        sentiment = input("Is the sentiment of this headline postive or negative?")
        print("---------")
        
        if sentiment=="2":
            
            df.iloc[row, 3] = "positive"

        elif sentiment=="1":

            df.iloc[row, 3] = "negative"

        elif sentiment=="3":

            df.iloc[row, 3] = "discard"

        else:

            print("Wrong Input!")

    return df.iloc[start:end,:]

# %% [markdown]
# # Loading the raw data

# %%
cnbc_df = pd.read_csv("Data/csv/cnbc_headlines.csv")
guardian_df = pd.read_csv("Data/csv/guardian_headlines.csv")
reuters_df = pd.read_csv("Data/csv/reuters_headlines.csv")

# %%
cnbc_df = cnbc_df["Headlines"].rename({"Headlines": "text"}, axis=1)
guardian_df = guardian_df["Headlines"].rename({"Headlines": "text"}, axis=1)
reuters_df = reuters_df["Headlines"].rename({"Headlines": "text"}, axis=1)

# %%
labeled_df = pd.read_csv("Data/csv/all-data.csv", encoding = "ISO-8859-1")
labeled_df
# Out:
#      sentiment                                               text
# 0      neutral  According to Gran , the company has no plans t...
# 1      neutral  Technopolis plans to develop in stages an area...
# 2     negative  The international electronic industry company ...
# 3     positive  With the new production plant the company woul...
# 4     positive  According to the company 's updated strategy f...
# ...        ...                                                ...
# 4841  negative  LONDON MarketWatch -- Share prices ended lower...
# 4842   neutral  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 4843  negative  Operating profit fell to EUR 35.4 mn from EUR ...
# 4844  negative  Net sales of the Paper segment decreased to EU...
# 4845  negative  Sales in Finland decreased by 10.5 % in Januar...
#
# [4846 rows x 2 columns]

# %%
labeled_df = rearrange_columns(labeled_df)

# %%
labeled_df
# Out:
#                                                    text sentiment
# 0     According to Gran , the company has no plans t...   neutral
# 1     Technopolis plans to develop in stages an area...   neutral
# 2     The international electronic industry company ...  negative
# 3     With the new production plant the company woul...  positive
# 4     According to the company 's updated strategy f...  positive
# ...                                                 ...       ...
# 4841  LONDON MarketWatch -- Share prices ended lower...  negative
# 4842  Rinkuskiai 's beer sales fell by 6.5 per cent ...   neutral
# 4843  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 4844  Net sales of the Paper segment decreased to EU...  negative
# 4845  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [4846 rows x 2 columns]

# %% [markdown]
# # Cleaning the data - removing rows with not unicode characters

# %%
mask = []
n_errors = 0

for row in range(len(labeled_df)):

    text = labeled_df.iloc[row, 0]
    
    file = open(f'temp.txt', "w")

    try:

        file.write(text)
        mask.append(True)

    except UnicodeEncodeError:
        
        mask.append(False)
        n_errors += 1

# %%
print(n_errors)
print(len(mask))
# Out:
# 74
# 4846

# %%
labeled_df = labeled_df[mask]
labeled_df
# Out:
#                                                    text sentiment
# 0     According to Gran , the company has no plans t...   neutral
# 1     Technopolis plans to develop in stages an area...   neutral
# 2     The international electronic industry company ...  negative
# 3     With the new production plant the company woul...  positive
# 4     According to the company 's updated strategy f...  positive
# ...                                                 ...       ...
# 4841  LONDON MarketWatch -- Share prices ended lower...  negative
# 4842  Rinkuskiai 's beer sales fell by 6.5 per cent ...   neutral
# 4843  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 4844  Net sales of the Paper segment decreased to EU...  negative
# 4845  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [4772 rows x 2 columns]

# %%
labeled_hl_df = labeled_df["text"]

# %%
financial_df = pd.concat([cnbc_df, guardian_df, reuters_df, labeled_hl_df], axis=0).reset_index(drop=True)

# %%
financial_df = pd.DataFrame(financial_df, columns=["text"]).dropna().reset_index(drop=True)

# %%
financial_df
# Out:
#                                                     text
# 0      Jim Cramer: A better way to invest in the Covi...
# 1         Cramer's lightning round: I would own Teradyne
# 2      Cramer's week ahead: Big week for earnings, ev...
# 3      IQ Capital CEO Keith Bliss says tech and healt...
# 4      Wall Street delivered the 'kind of pullback I'...
# ...                                                  ...
# 58137  LONDON MarketWatch -- Share prices ended lower...
# 58138  Rinkuskiai 's beer sales fell by 6.5 per cent ...
# 58139  Operating profit fell to EUR 35.4 mn from EUR ...
# 58140  Net sales of the Paper segment decreased to EU...
# 58141  Sales in Finland decreased by 10.5 % in Januar...
#
# [58142 rows x 1 columns]

# %%
financial_df.to_csv("Data/csv/fin_unlab.csv", index=False)

# %% [markdown]
# # Creating the large labelled dataset

# %%
labeled_df = labeled_df[(labeled_df["sentiment"]=="positive") | (labeled_df["sentiment"]=="negative")]
labeled_df
# Out:
#                                                    text sentiment
# 2     The international electronic industry company ...  negative
# 3     With the new production plant the company woul...  positive
# 4     According to the company 's updated strategy f...  positive
# 5     FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is ag...  positive
# 6     For the last quarter of 2010 , Componenta 's n...  positive
# ...                                                 ...       ...
# 4840  HELSINKI Thomson Financial - Shares in Cargote...  negative
# 4841  LONDON MarketWatch -- Share prices ended lower...  negative
# 4843  Operating profit fell to EUR 35.4 mn from EUR ...  negative
# 4844  Net sales of the Paper segment decreased to EU...  negative
# 4845  Sales in Finland decreased by 10.5 % in Januar...  negative
#
# [1945 rows x 2 columns]

# %%
train, test = train_test_split(labeled_df, test_size=0.2, stratify=labeled_df["sentiment"])

# %%
train["set"] = "train"
test["set"] = "test"

labeled_df = pd.concat([train, test], axis=0).reset_index(drop=True)
labeled_df
# Out:
#                                                    text sentiment    set
# 0     Operating cash flow after investments totalled...  negative  train
# 1     TietoEnator was down 1.13 pct to 18.38 , exten...  negative  train
# 2     In Finland 's Hobby Hall 's sales decreased by...  negative  train
# 3     Svyturys-Utenos Alus , which is controlled by ...  positive  train
# 4     `` Lining stone sales were also good in the ea...  positive  train
# ...                                                 ...       ...    ...
# 1940  The chain posted sales of 298 million euros fo...  positive   test
# 1941  Satama earned Data Management Solutions compet...  positive   test
# 1942  Rinkuskiai raised the sales by 18.1 percent , ...  positive   test
# 1943  Earnings per share ( EPS ) in the first half o...  negative   test
# 1944  Finnish technology group Aspocomp Group Oyj ( ...  positive   test
#
# [1945 rows x 3 columns]

# %%
labeled_df.to_csv("Data/csv/fin_lab_large.csv", index=False)

# %% [markdown]
# # Creating balanced train and test datasets

# %%
def build_balanced_ds(df, text_col, sent_col, list_labels=["positive", "negative"], ds_size=599*2, test_size=0.5, random_state=0):

    container = []
    label_size = int(ds_size/len(list_labels))
    split_index = int(np.floor(ds_size*test_size/len(list_labels)))

    for label in list_labels:

        label_df = (df[df.iloc[:, sent_col]==label]
                    .sample(label_size, random_state=random_state)
                    )

        label_test_df = label_df.iloc[0:split_index, :]
        label_test_df["set"] = "test"
        label_train_df = label_df.iloc[split_index:, :]
        label_train_df["set"] = "train"

        container.append(label_test_df)
        container.append(label_train_df)
        

    output_df = (pd.concat(container, axis=0)
                .sample(frac=1, random_state=random_state)
                .reset_index(drop=True)
                )

    return output_df

# %%
labeled_df["sentiment"].value_counts()
# Out:
# positive    1346
# negative     599
# Name: sentiment, dtype: int64

# %%
labeled_bal_df = build_balanced_ds(labeled_df, 0, 1, test_size=0.3)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_13440/3334901047.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label_test_df["set"] = "test"
# C:\Users\user\AppData\Local\Temp/ipykernel_13440/3334901047.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label_train_df["set"] = "train"

# %%
labeled_bal_df
labeled_bal_df.to_csv("Data/csv/fin_lab_bal.csv", index=False)

# %%
labeled_bal_df["sentiment"].value_counts(dropna=False)
# Out:
# positive    599
# negative    599
# Name: sentiment, dtype: int64

# %%
labeled_bal_df["set"].value_counts(dropna=False)
# Out:
# train    840
# test     358
# Name: set, dtype: int64

# %%
labeled_bal_df
# Out:
#                                                    text sentiment    set
# 0     The StoneGate UTM solution offers protection a...  positive  train
# 1     HELSINKI AFX - Outokumpu Technology said it ha...  positive  train
# 2     Finnish IT consultancy Satama Interactive Oyj ...  positive   test
# 3     HK Ruokatalo now accounts for about 50 % of po...  positive  train
# 4     Net cash flow from operating activities was a ...  negative   test
# ...                                                 ...       ...    ...
# 1193  Finnish Bank of +_land reports its operating p...  negative  train
# 1194  ( ADPnews ) - May 4 , 2010 - Finnish cutlery a...  negative   test
# 1195  Finnish developer and manufacturer of mobile p...  negative  train
# 1196  Comptel , a vendor of dynamic Operations Suppo...  positive  train
# 1197  As a result , 12 people will be made redundant...  negative   test
#
# [1198 rows x 3 columns]

# %% [markdown]
# # Building a folder with the headlines stored as text files

# %%
def build_folder(df, sent_col, text_col, set_col, labels_list = ["positive", "negative"]):

    root = "Data/financial"

    for set in ["train", "test"]:

        path = root + "/" + set

        if os.path.isdir(path):

            shutil.rmtree(path)
        
        for label in labels_list:

            path = path + "/" + label

            os.makedirs(path)

            path = root + "/" + set

    for row in tqdm(range(len(df))):

        text = df.iloc[row, text_col]
        sentiment = df.iloc[row, sent_col]
        set_label = df.iloc[row, set_col]

        file = open(f'Data/financial/{set_label}/{sentiment}/{row}.txt', "w")
        file.write(text)
        file.close()

# %%
build_folder(labeled_df, 1, 0, 2)
# Out:
# 100%|██████████| 1945/1945 [00:00<00:00, 2403.57it/s]

# %% [markdown]
# # Human supervision on highly uncertainty headlines

# %% [markdown]
# ## Reuters dataset

# %%
reuters_headlines_labelled_df = pd.read_csv("Data/csv/reuters_headlines_labeled.csv")

# %%
reuters_headlines_labelled_df
# Out:
#                                                     text  prob_pos  prob_neg  \
# 0      TikTok considers London and other locations fo...  0.814905  0.185095
# 1      Disney cuts ad spending on Facebook amid growi...  0.083292  0.916708
# 2      Trail of missing Wirecard executive leads to B...  0.957814  0.042186
# 3      Twitter says attackers downloaded data from up...  0.161916  0.838084
# 4      U.S. Republicans seek liability protections as...  0.325199  0.674801
# ...                                                  ...       ...       ...
# 32765  Malaysia says never hired British data firm at...       NaN       NaN
# 32766  Prosecutors search Volkswagen headquarters in ...       NaN       NaN
# 32767   McDonald's sets greenhouse gas reduction targets       NaN       NaN
# 32768  Pratt & Whitney to deliver spare A320neo engin...       NaN       NaN
# 32769  UK will always consider ways to improve data l...       NaN       NaN
#
#        certainty sentiment
# 0       0.629809  positive
# 1       0.833416  negative
# 2       0.915627  positive
# 3       0.676169  negative
# 4       0.349602  negative
# ...          ...       ...
# 32765        NaN       NaN
# 32766        NaN       NaN
# 32767        NaN       NaN
# 32768        NaN       NaN
# 32769        NaN       NaN
#
# [32770 rows x 5 columns]

# %%
top10_certain = reuters_headlines_labelled_df[['text', 'certainty', "sentiment"]].sort_values(by='certainty', ascending=False).head(10)

# %%
top10_certain = top10_certain.reset_index(drop=True)

# %%
(top10_certain["text"][1], top10_certain["sentiment"][1])
# Out:
# ('Burberry aims to woo more customers in China with Tencent tie-up',
#  'positive')

# %%
top_uncertain = reuters_headlines_labelled_df[['text', 'certainty', "sentiment"]].sort_values(by='certainty', ascending=True).head(200)

# %%
(reuters_headlines_labelled_df["text"][row], reuters_headlines_labelled_df["sentiment"][row], reuters_headlines_labelled_df["prob_pos"][row], reuters_headlines_labelled_df["prob_neg"][row])
# Out:
# ('Walmart to limit number of customers at stores as virus crisis deepens',
#  'negative',
#  0.3913768529891968,
#  0.6086231470108032)

# %%
top_uncertain["manual_sentiment"] = None
top_uncertain = top_uncertain.reset_index(drop=True)
top_uncertain
# Out:
#                                                   text  certainty sentiment  \
# 0    Boeing shares plummet as travel restrictions h...   0.000000  negative
# 1    U.S. opposes massive liquidity IMF boost: Mnuchin   0.000092  negative
# 2    Fiat Chrysler in talks over 6.3 billion euro s...   0.000153  positive
# 3    Fiat Chrysler chairman sees Peugeot deal final...   0.000244  negative
# 4    Saudi Arabia faces reality check as Wall Stree...   0.000244  negative
# ..                                                 ...        ...       ...
# 195  GM stops paying for health insurance for strik...   0.017332  negative
# 196  U.S. Energy Department urges Saudi, Russia to ...   0.017393  positive
# 197  Nissan to resume production at Spanish plant, ...   0.017393  negative
# 198  Venture firm Benchmark raises new fund without...   0.017393  positive
# 199  Ferrari to pilot 'Back on Track' employee scre...   0.017454  negative
#
#     manual_sentiment
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
# ..               ...
# 195             None
# 196             None
# 197             None
# 198             None
# 199             None
#
# [200 rows x 4 columns]

# %%
def manual_labeling(df, start, end):

    for row in range(start,end):

        text = df["text"][row]
        print(text)
        print("---------")
        sentiment = input("Is the sentiment of this headline postive or negative?")
        print("---------")
        
        if sentiment=="2":
            
            df.iloc[row, 3] = "positive"

        elif sentiment=="1":

            df.iloc[row, 3] = "negative"

        else:

            print("Wrong Input!")

# %%
manual_labeling(top_uncertain,150,200)
# Out:
# DoubleLine CEO Jeffrey Gundlach warns Fed rate cuts will not stop U.S. recession
# ---------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13440/3830271388.py in <module>
# ----> 1 manual_labeling(top_uncertain,150,200)
#
# ~\AppData\Local\Temp/ipykernel_13440/2664170086.py in manual_labeling(df, start, end)
#       6         print(text)
#       7         print("---------")
# ----> 8         sentiment = input("Is the sentiment of this headline postive or negative?")
#       9         print("---------")
#      10
#
# ~\miniconda3\envs\DA_ENV\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\miniconda3\envs\DA_ENV\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
reuters_labelled_newbatch = (top_uncertain.drop(["sentiment", "certainty"], axis=1)
                            .rename({"manual_sentiment": "sentiment"}, axis=1)
                            .iloc[100:200,:]
                            )

# %%
reuters_labelled_newbatch
# Out:
#                                                   text sentiment
# 100  'Am I going to get shot?' kids ask, as brands ...  negative
# 101  Credit Suisse revisits ex-U.S. employee's spyi...  negative
# 102  Indonesia readying measures to stabilize finan...  positive
# 103  Russia must press on with Nord Stream 2 gas li...  negative
# 104  Amazon and other large ecosystems at risk of r...  negative
# 105  Explainer: The jet subsidy row that threatens ...  negative
# 106  Here's what the new U.S. restrictions on Europ...  negative
# 107  Explainer: The jet subsidy row that threatens ...  negative
# 108  Hudson's Bay Co seeks to bolster Saks off-pric...  positive
# 109  U.S. Supreme Court clears way for pipeline to ...  positive
# 110  U.S. data point to moderate economic growth, t...  negative
# 111  Nissan sees cost of quitting Barcelona at up t...  negative
# 112  Oil refineries, offshore drillers face hurrica...  negative
# 113  Facebook agrees to pay UK fine over Cambridge ...  positive
# 114  China drives global oil demand recovery out of...  positive
# 115  Exclusive: Italian government leaning towards ...  positive
# 116  Euro zone GDP slows as expected in fourth-quar...  positive
# 117  U.S. court rules against Maduro bid to oust op...  positive
# 118  Opioid talks with Teva, distributors could res...  positive
# 119  Alibaba, Russian Post launch China-Russia flig...  positive
# 120  Pompeo tells Trudeau U.S. focused on release o...  negative
# 121   Oil prices rise as OPEC mulls deeper output cuts  positive
# 122  Elderly home turns to wearables for contact tr...  positive
# 123  Goldman wants traders to be more like dealmake...  negative
# 124  Illinois corn yields seen below average but im...  positive
# 125  Ad giant WPP pulls dividend, buyback and outlo...  negative
# 126           Factbox: Non OPEC+ crude oil supply cuts  negative
# 127  Advertising blitz, sugar-free Gatorade drive P...  positive
# 128  Hong Kong leader Carrie Lam says protests have...  negative
# 129  U.S. core inflation firming, but Fed still see...  negative
# 130  Explainer: How would a Schwab-TD Ameritrade de...  positive
# 131  Airbus jetliner deliveries recover some ground...  positive
# 132  Factbox: U.S. imposes Iran sanctions on China ...  negative
# 133  Kosovo confirms first coronavirus cases, an It...  negative
# 134  Facebook suspends Russian Instagram accounts t...  positive
# 135  'Broken system' starves U.S. oil boom of immig...  negative
# 136  Trump to announce 'guidelines' on reopening U....  positive
# 137  Brazil telecom carrier Oi may consider selling...  positive
# 138  Lufthansa says arbitrators propose fresh talks...  negative
# 139  Big investment banks have worst start to year ...  negative
# 140  Figure of $6.5 billion in loans for Air France...  negative
# 141  Five ways the Fed's rate cut could affect cons...  negative
# 142  U.S. effective fed funds rate jumps on Monday:...  positive
# 143  Nissan wants Renault to reduce stake to revive...  negative
# 144  Massive U.S. stock bounce stokes doubts, provo...  positive
# 145  Hungary ready to help Audi run local plant at ...  positive
# 146  U.S. bailout watchdog vows to scrutinize share...  negative
# 147  Cerberus wants well more than 7,000 job cuts a...  negative
# 148  Explainer: What 1.1 million foreign students c...  positive
# 149  Tesla can get support for German factory: Econ...  positive
# 150  DoubleLine CEO Jeffrey Gundlach warns Fed rate...  negative
# 151  Facebook's Libra could come under some existin...  negative
# 152  Fed's Harker says central bank works to keep m...  positive
# 153  Exclusive: Venezuelan shipping magnate faces U...  negative
# 154  Wall Street faces danger signs after best quar...  negative
# 155  15 U.S. states to jointly work to advance elec...  positive
# 156  McDonald's CEO surprise exit throws long-term ...  negative
# 157  U.S. services sector growth slows; employment ...  negative
# 158  U.S. SEC issues compliance focus areas for bro...  negative
# 159  Wall Street jumps after Monday's historic sell...  positive
# 160  Exclusive: UK supermarkets may cut services to...  negative
# 161  Exclusive: India reviewing anti-trust complain...  negative
# 162  Dudley's decade at the helm of BP almost didn'...  negative
# 163  OxyContin maker Purdue Pharma to pay states' l...  negative
# 164  Data show U.S. economy on solid footing as cor...  positive
# 165  Unilever's 'Fair & Lovely' to get makeover aft...  negative
# 166  Germany should make provisions to ensure banks...  negative
# 167  Global stocks succumb to shutdown fears but Ch...  negative
# 168  Oil futures edge up on talk of further OPEC+ s...  positive
# 169  Wall Street's sell-off deepens as coronavirus ...  negative
# 170  Modest Orange dividend overshadows European mo...  negative
# 171  China's GDP growth grinds to near 30-year low ...  negative
# 172  EasyJet not planning equity raise, doesn't rul...  positive
# 173  Nvidia forecasts sales above estimates, powere...  positive
# 174  Brazil's Gol values Boeing's 737 MAX compensat...  negative
# 175  Smithfield Foods shuts U.S. bacon, ham plants ...  negative
# 176  Ukraine to block entry to residents registered...  negative
# 177  Macy's posts nearly $4 billion in losses, does...  negative
# 178  Walmart faces pressure to stop gun sales after...  negative
# 179  SoulCycle, Equinox face boycott calls over inv...  negative
# 180  Boeing to offer voluntary layoffs to employees...  negative
# 181  Sanofi investigated over epilepsy drug linked ...  negative
# 182  United warns of cash bleed, empty planes even ...  negative
# 183  Peloton tumbles over 6% after short seller war...  negative
# 184  Kuwait foreign minister calls on armed forces ...  negative
# 185  Oil up 3% as countries ease lockdowns, product...  positive
# 186           Vodafone to close more than 1,000 stores  negative
# 187  Nestle's premium baby formula saw strong deman...  positive
# 188  Swiss says Airbus A220 flights resuming as eng...  positive
# 189  Carlos Ghosn says family played no role in esc...  negative
# 190  Fed includes 'heightened stress' in leveraged ...  negative
# 191  Bytedance's video app TikTok bans 'misleading ...  negative
# 192  Peloton gets lockdown boost as home workouts d...  positive
# 193  SoftBank is not 'SoftPunku' says CEO in defenc...  positive
# 194  Hand-holding in the pandemic: Wealth managers ...  negative
# 195  GM stops paying for health insurance for strik...  negative
# 196  U.S. Energy Department urges Saudi, Russia to ...  negative
# 197  Nissan to resume production at Spanish plant, ...  positive
# 198  Venture firm Benchmark raises new fund without...  positive
# 199  Ferrari to pilot 'Back on Track' employee scre...  negative

# %%
reuters_labelled = pd.concat([reuters_labelled,reuters_labelled_newbatch], axis=0)
reuters_labelled
# Out:
#                                                   text sentiment
# 0    Boeing shares plummet as travel restrictions h...  negative
# 1    U.S. opposes massive liquidity IMF boost: Mnuchin  negative
# 2    Fiat Chrysler in talks over 6.3 billion euro s...  positive
# 3    Fiat Chrysler chairman sees Peugeot deal final...  positive
# 4    Saudi Arabia faces reality check as Wall Stree...  negative
# ..                                                 ...       ...
# 195  GM stops paying for health insurance for strik...  negative
# 196  U.S. Energy Department urges Saudi, Russia to ...  negative
# 197  Nissan to resume production at Spanish plant, ...  positive
# 198  Venture firm Benchmark raises new fund without...  positive
# 199  Ferrari to pilot 'Back on Track' employee scre...  negative
#
# [200 rows x 2 columns]

# %%
labeled_df = labeled_df.drop(["set"], axis=1)

# %%
labeled_df = pd.concat([labeled_df, reuters_labelled], axis=0)

# %%
labeled_df
# Out:
#                                                   text sentiment
# 0    The borrower was happy to do the roadshow and ...  positive
# 1    The court found TelecomInvest 's arguments con...  positive
# 2    In addition to the Indian market , the new pla...  positive
# 3    Operating profit totalled EUR 9.0 mn , down fr...  negative
# 4    Biohit and VWR have been in close cooperation ...  positive
# ..                                                 ...       ...
# 195  GM stops paying for health insurance for strik...  negative
# 196  U.S. Energy Department urges Saudi, Russia to ...  negative
# 197  Nissan to resume production at Spanish plant, ...  positive
# 198  Venture firm Benchmark raises new fund without...  positive
# 199  Ferrari to pilot 'Back on Track' employee scre...  negative
#
# [2245 rows x 2 columns]

# %%
train, test = train_test_split(labeled_df, test_size=0.2, stratify=labeled_df["sentiment"])

# %%
train["set"] = "train"
test["set"] = "test"

labeled_df = pd.concat([train, test], axis=0).reset_index(drop=True)
labeled_df
# Out:
#                                                    text sentiment    set
# 0     The loss for the third quarter of 2007 was EUR...  positive  train
# 1     The company said that it will supply the WCDMA...  positive  train
# 2     ( ADPnews ) - Oct 21 , 2009 - Finland-based IT...  negative  train
# 3     This is the first time Finnair has been awarde...  positive  train
# 4     a January 11 , 2010 EPHC board of directors ha...  positive  train
# ...                                                 ...       ...    ...
# 2240  mn , and pretax profit to EUR 46.4 mn from EUR...  positive   test
# 2241  The situation of coated magazine printing pape...  negative   test
# 2242  Exclusive: U.S. states plan Google antitrust m...  negative   test
# 2243  The first ship has been delayed and is estimat...  negative   test
# 2244  U.S. Supreme Court clears way for pipeline to ...  positive   test
#
# [2245 rows x 3 columns]

# %%
labeled_df.to_csv("Data/financial/fin_labelled_large_reuters.csv", index=False)

# %% [markdown]
# ## Guardian dataset

# %%
guardian_headlines_labelled_df = pd.read_csv("Data/csv/guardian_headlines_labeled.csv")

# %%
guardian_headlines_labelled_df
# Out:
#                                                     text  prob_pos  prob_neg  \
# 0       Johnson is asking Santa for a Christmas recovery  0.452906  0.547094
# 1      ‘I now fear the worst’: four grim tales of wor...  0.182790  0.817210
# 2      Five key areas Sunak must tackle to serve up e...  0.650689  0.349311
# 3      Covid-19 leaves firms ‘fatally ill-prepared’ f...  0.634331  0.365669
# 4      The Week in Patriarchy  \n\n\n  Bacardi's 'lad...  0.974264  0.025736
# ...                                                  ...       ...       ...
# 17795  How investing in solar energy can create a bri...  0.987204  0.012797
# 17796     Poundland suppliers hit by insurance downgrade  0.068102  0.931898
# 17797  Cryptocurrencies: City watchdog to investigate...  0.964288  0.035712
# 17798  Unilever sells household name spreads to KKR f...  0.877687  0.122313
# 17799  The Guardian view on Ryanair’s model: a union-...  0.579259  0.420741
#
#        certainty sentiment
# 0       0.094187  negative
# 1       0.634420  negative
# 2       0.301379  positive
# 3       0.268662  positive
# 4       0.948528  positive
# ...          ...       ...
# 17795   0.974407  positive
# 17796   0.863795  negative
# 17797   0.928576  positive
# 17798   0.755373  positive
# 17799   0.158518  positive
#
# [17800 rows x 5 columns]

# %%
top10_certain = guardian_headlines_labelled_df[['text', 'certainty', "sentiment"]].sort_values(by='certainty', ascending=False).head(10)

# %%
top10_certain = top10_certain.reset_index(drop=True)

# %%
(top10_certain["text"][1], top10_certain["sentiment"][1])
# Out:
# ('Developing a new way of creating more homes', 'positive')

# %%
top_uncertain = guardian_headlines_labelled_df[['text', 'certainty', "sentiment"]].sort_values(by='certainty', ascending=True).head(300).reset_index(drop=True)

# %%
row=1

# %%
(top_uncertain["text"][row], top_uncertain["sentiment"][row])
# Out:
# ('Lockdown lifting: US exercise equipment sales soar amid pandemic',
#  'positive')

# %%
top_uncertain["manual_sentiment"] = None
top_uncertain
# Out:
#                                                   text  certainty sentiment  \
# 0    The long read  The George Soros philosophy – a...   0.000000  negative
# 1    Lockdown lifting: US exercise equipment sales ...   0.000061  positive
# 2    The Guardian view on His Dark Materials on the...   0.000099  positive
# 3    EasyJet founder offers £5m reward as he seeks ...   0.000244  positive
# 4    Business live  Government won't hold inquiry i...   0.000305  negative
# ..                                                 ...        ...       ...
# 295  Viewpoint column  \n\n\n  There's zero interes...   0.022945  negative
# 296  US insurer Chubb to stop investing in or selli...   0.023037  positive
# 297  Caledonian Sleeper suffers setbacks with Highl...   0.023067  positive
# 298  Record numbers switch electricity supplier ami...   0.023098  negative
# 299  Popular brands of UK sauce have excessive salt...   0.023311  negative
#
#     manual_sentiment
# 0               None
# 1               None
# 2               None
# 3               None
# 4               None
# ..               ...
# 295             None
# 296             None
# 297             None
# 298             None
# 299             None
#
# [300 rows x 4 columns]

# %%
batch1 = human_supervision(top_uncertain,100,250)
# Out:
# UK inflation hits six-month high as petrol and energy prices rise
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Harley-Davidson: Trump's tariffs pose grave threat to famous American name
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# BT unveils new logo after years of work – its name in a circle
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# 'Body blow for area': Bridgend devastated by Ford factory closure
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# UK living wage rises above inflation rate for 180,000 workers
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Fashion industry reels as coronavirus shuts shops and cancels orders
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Dominic Cummings accused of conflict of interest over NHS fund
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Debenhams comment by Sports Direct forces watchdog to intervene
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Business made simple  Secret Millionaire star Kavita Oberoi: 'The turning point was when I didn't get the promotion'
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Guardian Opinion cartoon  Martin Rowson on Heathrow's third runway – cartoon
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# The upside  String of British firms switch over to four-day working week
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Boohoo eyes struggling fashion brands after trading beats forecasts
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# After #MeToo  'It takes balls of steel': fighting UK supermarkets for equal pay
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Holiday Inn owner to ditch mini toiletries from 5,000 hotels
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# IMF tells US record growth is costing average citizens dear
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Project Syndicate economists
#
#
#   Trump hasn't improved on Nafta – but at least he hasn't blown up trade
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Weinstein Company fires chief operating officer David Glasser
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Use it or lose it: just hours left to put in PPI compensation claim
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Simon Fox to step down as chief of Daily Mirror owner Reach
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Why record job growth in America hides a troubling reality
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Whirlpool recalls more than 500,000 washing machines over fire risk
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Signs of the times: America's fading shopfronts – in pictures
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# MPs back Heathrow third runway project as Johnson faces criticism
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Revealed: how drugs giants can access your health records
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Your problems, with Anna Tims  As it’s the season of goodwill, praise be for these customer services
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Women's retirement age rising faster than men's in UK
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Broken capitalism
#
#
#   Yes, contemporary capitalism can be compatible with liberal democracy
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# White household income in UK 63% higher than black households, ONS finds
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Sky and BT will 'lose £1bn if sporting events stay shut until August'
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Retail slump has put 21,000 jobs at risk in 2018 so far
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Unemployment caused by coronavirus will leave deep scars in US
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Miriam Margolyes joins Mark Rylance's RSC boycott over BP
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Former Carillion finance directors expected to face investigation
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# UK environmentalists target Barclays in fossil fuels campaign
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Observer business agenda
#
#
#   M&S still feeling the heat as winter approaches
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# 'We're heartbroken': new starters trapped by furlough loophole
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Parliament to debate RBS 'hang themselves' comment
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Bank of England under pressure to shelve interest rate rise
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Patisserie Valerie boss quits and turnaround specialist steps in
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Neil Woodford's most disastrous stock choices – a roundup
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Next chief calls 2017 'toughest in 25 years' as profits slide by 8%
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# WPP chairman defends handling of Sir Martin Sorrell’s departure
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Nils Pratley on finance
#
#
#   Why should future whistleblowers believe they will be safe?
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# This is Europe  'There is a glimmer of hope': economists on coronavirus and capitalism
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# British businesses say new Brexit deal worse than May's agreement
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Fears of global economic slowdown as virus follows trade war
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Poundworld prepares to appoint administrators in bid to avert collapse
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Nissan tries to bar Carlos Ghosn from Rio property over corruption scandal
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# After mixed messages and mess-ups, Johnson bows to the inevitable
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# World's biggest fund manager vows to divest from thermal coal
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Daily Express editor calls its front pages 'downright offensive'
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Morrisons boss hands back £600,000 in bonuses
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Business leader
#
#
#   Raft of woeful forecasts spells an end to Trump’s economic bragging rights
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Martin Sorrell's resignation triggers 6.5% slide in WPP shares
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Potential bidders circle Thomas Cook as it hires turnaround specialist
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Carpetright to close 92 outlets, shedding hundreds of jobs
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Grosvenor Crescent rated the most expensive street in England and Wales
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Money talks
#
#
#   Retirement – can you make your pension last at least 20 years?
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# The race to find a coronavirus treatment has one major obstacle: big pharma
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# World Bank boss calls for more transparent lending to poor nations
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Comic Relief's Richard Curtis backs ethical pension campaign
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# No-deal Brexit threatens overseas territories
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Mexico could tighten migration controls to defuse Trump tariffs threat
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Freezing Britain and the chill wind of austerity
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Nils Pratley on finance
#
#
#   Ministers should move fast to protect incomes and employment
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# KPMG 'severely reprimanded' for audit failings at Co-op Bank
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Weatherwatch  Weatherwatch: The downs and ups of plane contrails
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Flybe falls prey to coronavirus and 'stronger' airlines are likely to follow
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Ban diesel cars from cities, say half of UK drivers in poll
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Deadly oil spill devastates Borneo port city – in pictures
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# George Soros makes £10.5m stock market bet against WH Smith
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Tesla investigates video of Model S car exploding
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Even Trump may ultimately retreat from the cost of the China trade war
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Covid-19 crisis opens doors to a leaner but meaner British Airways
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Observer business agenda
#
#
#   Ladbrokes owner GVC makes the running to beat pay revolt
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Animals farmed  How can you support farmers who are using fewer antibiotics?
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Southern Rail users miss flights after bottleneck at station
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Business live  Bank of England governor slams critics over Brexit analysis - as it happened
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Bounced cheques, cancelled flights – why do we still fly Ryanair?
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Covid-19 economic rescue plans must be green, say environmentalists
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Capitalism and the death of conservatism
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Lull at London City airport stokes fears of coronavirus impact
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Colgate launches vegan-certified toothpaste in recyclable tube
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Project Syndicate economists
#
#
#   Bernanke, Paulson and Geithner: revisiting the 2008 financial crisis
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Equality commission to investigate BBC over pay discrimination
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Amazon confirms it pays UK business rates of only £63.4m
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# US may be in recession amid Covid-19 crisis, says Fed chair Jerome Powell
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Consumer champions  Why won’t Barclays let me cancel my direct debit?
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Brexit anxiety for businesses 'at highest since referendum'
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Coronavirus spreads around the world – in pictures
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# 'Every £1 spent is a vote for how we want to live': Mary Portas on the high-street shops that will thrive after lockdown
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Nils Pratley on finance
#
#
#   An overhaul of Britain's railways was long overdue even before Covid-19
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Sales of hybrid cars soar as diesels plunge by nearly a quarter
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Nils Pratley on finance
#
#
#   George Osborne must understand the IMF role is no popularity contest
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Car price war and falling air fares cool UK inflation
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Foxtons profits plunge over London housing market slump
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Gulf petrodollars are a destructive addiction – the UK must kick the habit
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Gaucho to file for administration, with 1,500 jobs at risk
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Geneva goes electric: 2019 Motor Show – in pictures
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# St Mawes named UK’s top seaside resort in Which? poll
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# TSB crisis could drag into next week as bank turns to IBM
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Nils Pratley on finance
#
#
#   SoftBank punt on WeWork office space hub is risky business
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Wuhan facing 'wartime conditions' as global coronavirus deaths reach 724
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Former advertising executive reveals junk food-pushing tactics
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# HS2 was only ever about politics. And the battle will reach the heart of No 10
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Model companions: restaurant solves social distancing dilemma with mannequins
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Jeremy Hunt hits back at Airbus over Brexit warnings on jobs
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Boots criticised over failure to cut price of morning-after pill
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Nils Pratley on finance
#
#
#   'Melt-up' coinage could signal last hurrah for US stock market
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Nils Pratley on finance
#
#
#   Ferrexpo could have done without the side show to its Deloitte spat
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Elon Musk says Tesla planning 'thorough reorganization'
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Brexit uncertainty chills senior staff job market in UK
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# The People’s March, Waitrose and Lidl
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Banking royal commission condemns greed of financial sector in first report
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Nils Pratley on finance
#
#
#   It’s long past time to give auditors teeth
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Shoppers expected to spend more than £4bn on Boxing Day
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Cruise and Maritime Voyages in emergency talks after potential loan deal collapses
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Dixons Carphone CEO will step down to run chemist chain Boots
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Guardian Opinion cartoon  Ben Jennings on British Airways and data security – cartoon
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# US jobs report: record-breaking streak continues as 225,000 added in January
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Gambling watchdog fails to curb fixed-odds betting stakes to £2
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Justin Bieber remix of Despacito part of £200m song catalogue sale
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Trump may seek separate Nafta talks with Canada and Mexico
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# The Final Days of EMI: Selling the Pig by Eamonn Forde – review
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# New car sales in UK plunge by 44% as coronavirus bites
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Bankers work around the clock to iron out EU finance reforms
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# East coast line bailout puts rail privatisation back in spotlight
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# How high street shops in England plan to trade from Monday
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# House of Fraser’s survival bid creates anger and fear
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Hardy Amies fashion house falls into administration
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Kshama Sawant wants to tax Amazon so people can afford to live in Seattle. Can she pull it off?
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# The recession risk  Is a global recession coming? Here are seven warning signs
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Trump considers block on crude oil imports to prop up US market
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Hammerson offloads nine UK retail parks for £455m
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Book of the day  Bitcoin Billionaires by Ben Mezrich review – the tale of the Winklevoss twins
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Big tech companies are trying to rewrite the rules to get your data
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Drax power plant to stop burning coal, with loss of 230 jobs
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Business live  Jaguar Land Rover to cut production and 1,000 jobs in the Midlands – as it happened
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# UK income inequality increasing as benefits cuts hit poorest
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# 'Coal is over': the miners rooting for the Green New Deal
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Here in Liverpool, we know what northern austerity looks like up close
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# UK needs 'biggest-ever peacetime job creation plan' to stop mass unemployment
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# Business live  Stock market turmoil wipes £56bn off FTSE 100, in worst day since Brexit vote - as it happened
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Economics viewpoint
#
#
#   Saudi Arabia has the most to lose from a sharp rise in oil prices
# ---------
# Is the sentiment of this headline postive or negative?1
# ---------
# Larry Cohen, cult exploitation director, dies aged 77
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# The panel
#
#
#   2020 budget: the Guardian panel’s verdict
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Pressure grows for developing world debt relief over coronavirus
# ---------
# Is the sentiment of this headline postive or negative?2
# ---------
# York shop bans cheesy Christmas music for sake of staff
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# UK manufacturing sector ‘far larger than politicians realise’
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------
# Wales is doing it. So why won’t Westminster support the UK steel industry?
# ---------
# Is the sentiment of this headline postive or negative?3
# ---------

# %%
batch1_cleaned = (batch1.drop(["sentiment", "certainty"], axis=1)
                            .rename({"manual_sentiment": "sentiment"}, axis=1)
                 )

# %%
batch1_cleaned
# Out:
#                                                   text sentiment
# 100  UK inflation hits six-month high as petrol and...  negative
# 101  Harley-Davidson: Trump's tariffs pose grave th...  negative
# 102  BT unveils new logo after years of work – its ...  negative
# 103  'Body blow for area': Bridgend devastated by F...  negative
# 104  UK living wage rises above inflation rate for ...  positive
# ..                                                 ...       ...
# 245  The panel  \n\n\n  2020 budget: the Guardian p...   discard
# 246  Pressure grows for developing world debt relie...  positive
# 247  York shop bans cheesy Christmas music for sake...   discard
# 248  UK manufacturing sector ‘far larger than polit...   discard
# 249  Wales is doing it. So why won’t Westminster su...   discard
#
# [150 rows x 2 columns]

# %%
labeled_df = labeled_df.drop(["set"], axis=1)

# %%
labeled_df
# Out:
#                                                    text sentiment
# 0     The company reported today an operating loss o...  negative
# 1     Global sports equipment maker Amer Sports Corp...  positive
# 2     `` The second quarter of 2010 was the firstqua...  positive
# 3          Net sales surged by 30 % to EUR 36 million .  positive
# 4     25 March 2011 - Finnish electronics contract m...  negative
# ...                                                 ...       ...
# 1940  The rebuilds are designed to improve the machi...  positive
# 1941  Operating profit rose to EUR 4.7 mn from EUR 3...  positive
# 1942  In January-September 2007 , Finnlines ' net sa...  positive
# 1943  According to A-Rehu 's Managing Director , Jou...  positive
# 1944  The world 's biggest magazine paper maker said...  positive
#
# [1945 rows x 2 columns]

# %%
labeled_df = pd.concat([labeled_df, batch_cleaned, batch1_cleaned], axis=0)

# %%
labeled_df = labeled_df[labeled_df["sentiment"] != "discard"]
labeled_df
# Out:
#                                                   text sentiment
# 0    The company reported today an operating loss o...  negative
# 1    Global sports equipment maker Amer Sports Corp...  positive
# 2    `` The second quarter of 2010 was the firstqua...  positive
# 3         Net sales surged by 30 % to EUR 36 million .  positive
# 4    25 March 2011 - Finnish electronics contract m...  negative
# ..                                                 ...       ...
# 240  Here in Liverpool, we know what northern auste...  negative
# 241  UK needs 'biggest-ever peacetime job creation ...  positive
# 242  Business live  Stock market turmoil wipes £56b...  negative
# 243  Economics viewpoint  \n\n\n  Saudi Arabia has ...  negative
# 246  Pressure grows for developing world debt relie...  positive
#
# [2119 rows x 2 columns]

# %%
train, test = train_test_split(labeled_df, test_size=0.2, stratify=labeled_df["sentiment"])

# %%
train["set"] = "train"
test["set"] = "test"

labeled_df = pd.concat([train, test], axis=0).reset_index(drop=True)
labeled_df
# Out:
#                                                    text sentiment    set
# 0     Vaisala Oyj Press Release September 30 , 2010 ...  positive  train
# 1     Operating profit totaled EUR 3.8 mn , down fro...  negative  train
# 2     The negotiation has resulted in the reduction ...  negative  train
# 3     Tekla will implement the renewal in software v...  positive  train
# 4     Publishing Sweden 's operating loss was EUR 1....  negative  train
# ...                                                 ...       ...    ...
# 2114  The company said that the fall in turnover had...  negative   test
# 2115  Consolidated operating profit from continuing ...  negative   test
# 2116  Incap Contract Manufacturing Services Private ...  positive   test
# 2117  Operating profit rose to EUR 4.7 mn from EUR 4...  positive   test
# 2118  Business live  Government won't hold inquiry i...  positive   test
#
# [2119 rows x 3 columns]

# %%
labeled_df.to_csv("Data/csv/fin_labelled_large_imp3.csv", index=False)

# %%
guardian_labelled_humansup_df = pd.concat([batch, batch1], axis=0)
guardian_labelled_humansup_df
# Out:
#                                                   text  certainty sentiment  \
# 0    The long read  The George Soros philosophy – a...   0.000000  negative
# 1    Lockdown lifting: US exercise equipment sales ...   0.000061  positive
# 2    The Guardian view on His Dark Materials on the...   0.000099  positive
# 3    EasyJet founder offers £5m reward as he seeks ...   0.000244  positive
# 4    Business live  Government won't hold inquiry i...   0.000305  negative
# ..                                                 ...        ...       ...
# 245  The panel  \n\n\n  2020 budget: the Guardian p...   0.018919  positive
# 246  Pressure grows for developing world debt relie...   0.018919  positive
# 247  York shop bans cheesy Christmas music for sake...   0.018964  negative
# 248  UK manufacturing sector ‘far larger than polit...   0.019010  positive
# 249  Wales is doing it. So why won’t Westminster su...   0.019041  negative
#
#     manual_sentiment
# 0            discard
# 1           negative
# 2            discard
# 3           negative
# 4           positive
# ..               ...
# 245          discard
# 246         positive
# 247          discard
# 248          discard
# 249          discard
#
# [250 rows x 4 columns]

# %%
guardian_labelled_humansup_df.to_csv("Data/csv/guardian_headlines_labeled_humansup.csv", index=False)

# %%
labeled_df = pd.read_csv("Data/csv/fin_labelled_large_imp3.csv")

# %%
build_folder(labeled_df, 1,0,2)
# Out:
# 100%|██████████| 2119/2119 [00:00<00:00, 2364.78it/s]
