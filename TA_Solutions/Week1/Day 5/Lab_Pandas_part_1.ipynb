# %% [markdown]
# # Using Pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 200)
## to make it possible to display multiple output inside one cell 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# <b>load the data from the vehicles.csv file into pandas data frame

# %%
vehicles_df = pd.read_csv("Data/vehicles.csv")

# %% [markdown]
# First exploration of the dataset:
#
# - How many observations does it have?
#   **35,952 records**
# - Look at all the columns: do you understand what they mean?
#   **Engine Displacement** - measure of the cylinder volume and therefore loose indicator of the power
#   **MPG** - miles per gallon (measure of fuel consumption)
# - Look at the raw data: do you see anything weird?
#   **No**
# - Look at the data types: are they the expected ones for the information the column contains?
#   **Cylinders** - it could be integer
#   **Transmission** - could be changed to a binary variable (manual and auto)

# %%
vehicles_df
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# 0            4.0  Automatic 3-spd     2-Wheel Drive
# 1            6.0  Automatic 3-spd     2-Wheel Drive
# 2            4.0  Automatic 3-spd  Rear-Wheel Drive
# 3            6.0  Automatic 3-spd  Rear-Wheel Drive
# 4            6.0  Automatic 4-spd  Rear-Wheel Drive
# ...          ...              ...               ...
# 35947        3.0        Auto(AM5)  Rear-Wheel Drive
# 35948        3.0        Auto(AM5)  Rear-Wheel Drive
# 35949        3.0        Auto(AM5)  Rear-Wheel Drive
# 35950        3.0        Auto(AM6)  Rear-Wheel Drive
# 35951        3.0     Manual 5-spd  Rear-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 0      Special Purpose Vehicle 2WD   Regular          19.388824        18
# 1      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 2      Special Purpose Vehicle 2WD   Regular          20.600625        16
# 3      Special Purpose Vehicle 2WD   Regular          25.354615        13
# 4                     Midsize Cars   Premium          20.600625        14
# ...                            ...       ...                ...       ...
# 35947                  Two Seaters   Premium           9.155833        34
# 35948                  Two Seaters   Premium           9.155833        34
# 35949                  Two Seaters   Premium           9.155833        34
# 35950                  Two Seaters   Premium           9.155833        34
# 35951                  Two Seaters   Premium           9.417429        32
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               17            17               522.764706            1950
# 1               13            13               683.615385            2550
# 2               17            16               555.437500            2100
# 3               13            13               683.615385            2550
# 4               21            16               555.437500            2550
# ...            ...           ...                      ...             ...
# 35947           38            36               244.000000            1100
# 35948           38            36               243.000000            1100
# 35949           38            36               244.000000            1100
# 35950           39            36               246.000000            1100
# 35951           39            35               255.000000            1150
#
# [35952 rows x 15 columns]

# %%
type(vehicles_df["Make"].value_counts())
# Out:
# pandas.core.series.Series

# %%
# Function to store in dictionary the number of nan values per column

def nan_counter(df):
    
    """
    Returns a dictionary containing the number of nan values per column (for dataframe df)

    Parameters
    ----------
    df : Pandas dataframe

    Returns
    -------
    remaining_nan : Dictionary
        Contains the number of nan values in each column of the dataframe

    """
    
    remaining_nan = {}

    for column in df.columns:

        remaining_nan[column] = df[column][df[column].isna() == True].size

    return remaining_nan

# %%
nan_counter(vehicles_df)
# Out:
# {'Make': 0,
#  'Model': 0,
#  'Year': 0,
#  'Engine Displacement': 0,
#  'Cylinders': 0,
#  'Transmission': 0,
#  'Drivetrain': 0,
#  'Vehicle Class': 0,
#  'Fuel Type': 0,
#  'Fuel Barrels/Year': 0,
#  'City MPG': 0,
#  'Highway MPG': 0,
#  'Combined MPG': 0,
#  'CO2 Emission Grams/Mile': 0,
#  'Fuel Cost/Year': 0}

# %%
vehicles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
#  14  Fuel Cost/Year           35952 non-null  int64
# dtypes: float64(4), int64(5), object(6)
# memory usage: 4.1+ MB

# %% [markdown]
# ### Cleaning and wrangling data
#
# - Some car brand names refer to the same brand. Replace all brand names that contain the word "Dutton" for simply "Dutton". If you find similar examples, clean their names too. Use `loc` with boolean indexing.
#
# - Convert CO2 Emissions from Grams/Mile to Grams/Km
#
# - Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` and .
#
# - convert MPG columns to km_per_liter

# %% [markdown]
# #### Car Brand Names

# %%
brands = (pd.DataFrame(vehicles_df["Make"].value_counts())
            .reset_index()
            .rename(columns={"index":"Brand"})
            .sort_values(by="Brand", ascending=True)
         )

# %%
brands
# Out:
#                                   Brand  Make
# 78                           AM General     4
# 110                    ASC Incorporated     1
# 33                                Acura   302
# 52                           Alfa Romeo    41
# 57          American Motors Corporation    22
# 41                         Aston Martin   133
# 11                                 Audi   890
# 112                     Aurora Cars Ltd     1
# 83                    Autokraft Limited     4
# 5                                   BMW  1677
# 89                           BMW Alpina     3
# 42                              Bentley   116
# 75                              Bertone     5
# 95        Bill Dovell Motor Car Company     2
# 90               Bitter Gmbh and Co. Kg     3
# 68                              Bugatti     8
# 20                                Buick   537
# 93                      CCC Engineering     2
# 61                        CX Automotive    16
# 23                             Cadillac   508
# 0                             Chevrolet  3643
# 19                             Chrysler   641
# 88             Consulier Industries Inc     3
# 87           Dabryan Coach Builders Inc     3
# 86                                Dacia     3
# 47                               Daewoo    67
# 60                             Daihatsu    17
# 2                                 Dodge  2360
# 125                  E. P. Dutton, Inc.     1
# 38                                Eagle   156
# 124    Environmental Rsch and Devp Corp     1
# 85                    Evans Automobiles     3
# 122                     Excalibur Autos     1
# 63                        Federal Coach    14
# 36                              Ferrari   208
# 51                                 Fiat    43
# 118                              Fisker     1
# 1                                  Ford  2946
# 3                                   GMC  2347
# 117                      General Motors     1
# 70                              Genesis     7
# 39                                  Geo   144
# 116                            Goldacre     1
# 107           Grumman Allied Industries     1
# 80                        Grumman Olson     4
# 13                                Honda   836
# 59                               Hummer    19
# 18                              Hyundai   662
# 103       Import Foreign Auto Sales Inc     1
# 64                Import Trade Services    13
# 30                             Infiniti   345
# 111                    Isis Imports Ltd     1
# 27                                Isuzu   409
# 53                          J.K. Motors    36
# 113                 JBA Motorcars, Inc.     1
# 31                               Jaguar   343
# 14                                 Jeep   829
# 24                                  Kia   493
# 99               Laforza Automobile Inc     2
# 126              Lambda Control Systems     1
# 44                          Lamborghini   104
# 40                           Land Rover   142
# 28                                Lexus   397
# 35                              Lincoln   273
# 105                 London Coach Co Inc     1
# 104                         London Taxi     1
# 50                                Lotus    53
# 32                                 MINI   320
# 114                            Mahindra     1
# 43                             Maserati   111
# 56                              Maybach    31
# 10                                Mazda   915
# 65                   McLaren Automotive    13
# 72                        Mcevoy Motors     6
# 6                         Mercedes-Benz  1284
# 21                              Mercury   532
# 62                               Merkur    14
# 9                            Mitsubishi   950
# 100               Mobility Ventures LLC     2
# 84                               Morgan     3
# 7                                Nissan  1253
# 29                           Oldsmobile   376
# 102                       PAS Inc - GMC     2
# 98                             PAS, Inc     2
# 97                               Pagani     2
# 120                               Panos     1
# 121              Panoz Auto-Development     1
# 76          Panther Car Company Limited     4
# 46                              Peugeot    74
# 101                         Pininfarina     2
# 25                             Plymouth   456
# 15                              Pontiac   784
# 12                              Porsche   862
# 96                 Quantum Technologies     2
# 106                               Qvale     1
# 48                                  Ram    57
# 94                       Red Shift Ltd.     2
# 54                              Renault    33
# 37                          Rolls-Royce   160
# 49                    Roush Performance    53
# 92                  Ruf Automobile Gmbh     2
# 123  S and S Coach Company  E.p. Dutton     1
# 91                                  SRT     2
# 26                                 Saab   410
# 73                               Saleen     5
# 77                   Saleen Performance     4
# 34                               Saturn   278
# 45                                Scion    83
# 119                              Shelby     1
# 66                               Spyker    13
# 67                             Sterling    12
# 16                               Subaru   781
# 115    Superior Coaches Div E.p. Dutton     1
# 22                               Suzuki   512
# 79                  TVR Engineering Ltd     4
# 71                          Tecstar, LP     6
# 81                  Texas Coach Company     4
# 4                                Toyota  1836
# 74                                  VPG     5
# 82                               Vector     4
# 108                 Vixen Motor Company     1
# 109         Volga Associated Automobile     1
# 8                            Volkswagen  1047
# 17                                Volvo   717
# 55                Wallace Environmental    32
# 69                                 Yugo     8
# 58                                smart    20

# %%
mask_dutton = vehicles_df["Make"].apply(lambda x: "Dutton" in x)
vehicles_df[mask_dutton]
# Out:
#                                      Make               Model  Year  \
# 11012                  E. P. Dutton, Inc.       Funeral Coach  1985
# 30164  S and S Coach Company  E.p. Dutton  Funeral Coach  2WD  1984
# 31754    Superior Coaches Div E.p. Dutton  Funeral Coach  2WD  1984
#
#        Engine Displacement  Cylinders     Transmission         Drivetrain  \
# 11012                  4.1        8.0  Automatic 4-spd  Front-Wheel Drive
# 30164                  6.0        8.0  Automatic 3-spd      2-Wheel Drive
# 31754                  6.0        8.0  Automatic 3-spd      2-Wheel Drive
#
#                      Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 11012     Special Purpose Vehicles   Regular          19.388824        15
# 30164  Special Purpose Vehicle 2WD   Regular          32.961000         9
# 31754  Special Purpose Vehicle 2WD   Regular          32.961000        10
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 11012           21            17               522.764706            1950
# 30164           11            10               888.700000            3350
# 31754           11            10               888.700000            3350

# %%
vehicles_df[vehicles_df["Make"].str.contains("Dutton")]
# Out:
#          Make               Model  Year  Engine Displacement  Cylinders  \
# 11012  Dutton       Funeral Coach  1985                  4.1        8.0
# 30164  Dutton  Funeral Coach  2WD  1984                  6.0        8.0
# 31754  Dutton  Funeral Coach  2WD  1984                  6.0        8.0
#
#       Transmission         Drivetrain                Vehicle Class Fuel Type  \
# 11012    automatic  Front-Wheel Drive     Special Purpose Vehicles   Regular
# 30164    automatic      2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 31754    automatic      2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11012          19.388824        15           21            17
# 30164          32.961000         9           11            10
# 31754          32.961000        10           11            10
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year  CO2 Emission Grams/Km  \
# 11012               522.764706            1950             324.831736
# 30164               888.700000            3350             552.213951
# 31754               888.700000            3350             552.213951
#
#        City Km/L  Highway Km/L  Combined Km/L
# 11012   6.377665      8.928731       7.228020
# 30164   3.826599      4.676954       4.251777
# 31754   4.251777      4.676954       4.251777

# %%
vehicles_df["Make"].where(~ mask_dutton, "Dutton", inplace=True)

# %%
vehicles_df[mask_dutton]
# Out:
#          Make               Model  Year  Engine Displacement  Cylinders  \
# 11012  Dutton       Funeral Coach  1985                  4.1        8.0
# 30164  Dutton  Funeral Coach  2WD  1984                  6.0        8.0
# 31754  Dutton  Funeral Coach  2WD  1984                  6.0        8.0
#
#           Transmission         Drivetrain                Vehicle Class  \
# 11012  Automatic 4-spd  Front-Wheel Drive     Special Purpose Vehicles
# 30164  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
# 31754  Automatic 3-spd      2-Wheel Drive  Special Purpose Vehicle 2WD
#
#       Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11012   Regular          19.388824        15           21            17
# 30164   Regular          32.961000         9           11            10
# 31754   Regular          32.961000        10           11            10
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 11012               522.764706            1950
# 30164               888.700000            3350
# 31754               888.700000            3350

# %% [markdown]
# #### Convert CO2 Emissions from Grams/Mile to Grams/Km

# %%
conversion_ratio_mile_km = 1 / 1.60934

# %%
co2_emission_grams_km = (vehicles_df["CO2 Emission Grams/Mile"]*conversion_ratio_mile_km)

# %%
vehicles_df["CO2 Emission Grams/Km"] = co2_emission_grams_km
vehicles_df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year  CO2 Emission Grams/Km
# 0               522.764706            1950             324.831736
# 1               683.615385            2550             424.779962
# 2               555.437500            2100             345.133719
# 3               683.615385            2550             424.779962
# 4               555.437500            2550             345.133719

# %% [markdown]
# #### binary colum

# %%
vehicles_df["Transmission"].value_counts()
# Out:
# Automatic 4-spd                     10585
# Manual 5-spd                         7787
# Automatic (S6)                       2631
# Automatic 3-spd                      2597
# Manual 6-spd                         2423
# Automatic 5-spd                      2171
# Automatic 6-spd                      1432
# Manual 4-spd                         1306
# Automatic (S8)                        960
# Automatic (S5)                        822
# Automatic (variable gear ratios)      675
# Automatic 7-spd                       662
# Automatic (S7)                        261
# Auto(AM-S7)                           256
# Automatic 8-spd                       243
# Automatic (S4)                        229
# Auto(AM7)                             157
# Auto(AV-S6)                           145
# Auto(AM6)                             110
# Auto(AM-S6)                            92
# Automatic 9-spd                        90
# Manual 3-spd                           74
# Manual 7-spd                           68
# Auto(AV-S7)                            63
# Auto(AV-S8)                            26
# Automatic (S9)                         26
# Auto(AM5)                              12
# Automatic (AV-S6)                       9
# Auto(AM-S8)                             6
# Auto(AM8)                               5
# Automatic (AV)                          4
# Automatic (A6)                          4
# Automatic (A1)                          3
# Manual(M7)                              3
# Auto (AV)                               2
# Auto(L4)                                2
# Auto(L3)                                2
# Automatic (AM5)                         2
# Auto(AM-S9)                             1
# Automatic 6spd                          1
# Auto (AV-S6)                            1
# Auto (AV-S8)                            1
# Auto(A1)                                1
# Automatic (AM6)                         1
# Manual 5 spd                            1
# Name: Transmission, dtype: int64

# %%
vehicles_df["Transmission"] = vehicles_df["Transmission"].map(lambda x: "automatic" if "Auto" in x else "manual")

# %%
vehicles_df["Transmission"].head
# Out:
# <bound method NDFrame.head of 0        automatic
# 1        automatic
# 2        automatic
# 3        automatic
# 4        automatic
#            ...
# 35947    automatic
# 35948    automatic
# 35949    automatic
# 35950    automatic
# 35951       manual
# Name: Transmission, Length: 35952, dtype: object>

# %% [markdown]
# #### convert MPG columns to km_per_liter

# %%
conversion_ratio_mpg_kmliter = 1.60934 / 3.7851

# %%
city_kmliter = (vehicles_df["City MPG"]*conversion_ratio_mpg_kmliter)
highway_kmliter = (vehicles_df["Highway MPG"]*conversion_ratio_mpg_kmliter)
combined_kmliter = (vehicles_df["Combined MPG"]*conversion_ratio_mpg_kmliter)

# %%
vehicles_df["City Km/L"] = city_kmliter
vehicles_df["Highway Km/L"] = highway_kmliter
vehicles_df["Combined Km/L"] = combined_kmliter
vehicles_df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders Transmission        Drivetrain                Vehicle Class  \
# 0        4.0    automatic     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0    automatic     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0    automatic  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0    automatic  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0    automatic  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year  CO2 Emission Grams/Km  City Km/L  \
# 0               522.764706            1950             324.831736   7.653198
# 1               683.615385            2550             424.779962   5.527310
# 2               555.437500            2100             345.133719   6.802843
# 3               683.615385            2550             424.779962   5.527310
# 4               555.437500            2550             345.133719   5.952487
#
#    Highway Km/L  Combined Km/L
# 0      7.228020       7.228020
# 1      5.527310       5.527310
# 2      7.228020       6.802843
# 3      5.527310       5.527310
# 4      8.928731       6.802843

# %% [markdown]
# Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Grams/Mile * Mile/Km -> Grams/Mile * 1 Mile/1.60934Km
#
# $$ \frac{Grams}{Mile} * \frac{Mile}{Km} $$
#
# $$ \frac{Grams}{Mile} * \frac{1 Mile}{1.60934Km}  $$

# %% [markdown]
# convert MPG columns to km_per_liter
#
# MPG = Miles/Gallon -> Km/Liter
#
# 1 Mile = 1.60934 Km
#
# 1 Gallon = 3.78541 Liters
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{Km}{Miles} * \frac{Gallon}{Liters}$$
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{1.60934Km}{ 1Miles} * \frac{1 Gallon}{3.78541 Liters}$$
#
# * ( 1.60934 / 3.78541 )

# %% [markdown]
# ### Gathering insights:
#
# - How many car makers are there? How many models? Which car maker has the most cars in the dataset?
#
# - When were these cars made? How big is the engine of these cars?
#
# - What's the frequency of different transmissions, drivetrains and fuel types?
#
# - What's the car that consumes the least/most fuel?

# %% [markdown]
# #### How many car makers are there? How many models? Which car maker has the most cars in the dataset?

# %%
vehicles_df.nunique()
# Out:
# Make                        125
# Model                      3608
# Year                         34
# Engine Displacement          65
# Cylinders                     9
# Transmission                  2
# Drivetrain                    8
# Vehicle Class                34
# Fuel Type                    13
# Fuel Barrels/Year           123
# City MPG                     48
# Highway MPG                  49
# Combined MPG                 46
# CO2 Emission Grams/Mile     575
# Fuel Cost/Year               55
# CO2 Emission Grams/Km       575
# City Km/L                    48
# Highway Km/L                 49
# Combined Km/L                46
# dtype: int64

# %%
(pd.DataFrame(vehicles_df["Make"].value_counts())
                                 .sort_values(by="Make", ascending=False)
)
# Out:
#                                   Make
# Chevrolet                         3643
# Ford                              2946
# Dodge                             2360
# GMC                               2347
# Toyota                            1836
# BMW                               1677
# Mercedes-Benz                     1284
# Nissan                            1253
# Volkswagen                        1047
# Mitsubishi                         950
# Mazda                              915
# Audi                               890
# Porsche                            862
# Honda                              836
# Jeep                               829
# Pontiac                            784
# Subaru                             781
# Volvo                              717
# Hyundai                            662
# Chrysler                           641
# Buick                              537
# Mercury                            532
# Suzuki                             512
# Cadillac                           508
# Kia                                493
# Plymouth                           456
# Saab                               410
# Isuzu                              409
# Lexus                              397
# Oldsmobile                         376
# Infiniti                           345
# Jaguar                             343
# MINI                               320
# Acura                              302
# Saturn                             278
# Lincoln                            273
# Ferrari                            208
# Rolls-Royce                        160
# Eagle                              156
# Geo                                144
# Land Rover                         142
# Aston Martin                       133
# Bentley                            116
# Maserati                           111
# Lamborghini                        104
# Scion                               83
# Peugeot                             74
# Daewoo                              67
# Ram                                 57
# Lotus                               53
# Roush Performance                   53
# Fiat                                43
# Alfa Romeo                          41
# J.K. Motors                         36
# Renault                             33
# Wallace Environmental               32
# Maybach                             31
# American Motors Corporation         22
# smart                               20
# Hummer                              19
# Daihatsu                            17
# CX Automotive                       16
# Federal Coach                       14
# Merkur                              14
# Import Trade Services               13
# Spyker                              13
# McLaren Automotive                  13
# Sterling                            12
# Bugatti                              8
# Yugo                                 8
# Genesis                              7
# Tecstar, LP                          6
# Mcevoy Motors                        6
# Bertone                              5
# VPG                                  5
# Saleen                               5
# Texas Coach Company                  4
# TVR Engineering Ltd                  4
# Autokraft Limited                    4
# Vector                               4
# Grumman Olson                        4
# AM General                           4
# Saleen Performance                   4
# Panther Car Company Limited          4
# Dabryan Coach Builders Inc           3
# Morgan                               3
# Dutton                               3
# Dacia                                3
# Consulier Industries Inc             3
# BMW Alpina                           3
# Evans Automobiles                    3
# Bitter Gmbh and Co. Kg               3
# PAS, Inc                             2
# Quantum Technologies                 2
# Pininfarina                          2
# Red Shift Ltd.                       2
# Pagani                               2
# SRT                                  2
# Mobility Ventures LLC                2
# PAS Inc - GMC                        2
# Laforza Automobile Inc               2
# Bill Dovell Motor Car Company        2
# Ruf Automobile Gmbh                  2
# CCC Engineering                      2
# Environmental Rsch and Devp Corp     1
# Qvale                                1
# Excalibur Autos                      1
# Panoz Auto-Development               1
# Panos                                1
# Fisker                               1
# Shelby                               1
# General Motors                       1
# Goldacre                             1
# Grumman Allied Industries            1
# London Taxi                          1
# Import Foreign Auto Sales Inc        1
# London Coach Co Inc                  1
# JBA Motorcars, Inc.                  1
# Vixen Motor Company                  1
# Volga Associated Automobile          1
# Aurora Cars Ltd                      1
# ASC Incorporated                     1
# Mahindra                             1
# Isis Imports Ltd                     1
# Lambda Control Systems               1

# %% [markdown]
# #### What's the car that consumes the least/most fuel?
# #### When were these cars made? How big is the engine of these cars?

# %%
# Car with minimum consumption

vehicles_df[vehicles_df["Combined Km/L"] == np.max(vehicles_df["Combined Km/L"])]
# Out:
#          Make      Model  Year  Engine Displacement  Cylinders Transmission  \
# 33279  Toyota  Prius Eco  2016                  1.8        4.0    automatic
# 33280  Toyota  Prius Eco  2017                  1.8        4.0    automatic
#
#               Drivetrain Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 33279  Front-Wheel Drive  Midsize Cars   Regular           5.885893        58
# 33280  Front-Wheel Drive  Midsize Cars   Regular           5.885893        58
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year  \
# 33279           53            56                    158.0             600
# 33280           53            56                    158.0             600
#
#        CO2 Emission Grams/Km  City Km/L  Highway Km/L  Combined Km/L
# 33279              98.176892  24.660305     22.534417       23.80995
# 33280              98.176892  24.660305     22.534417       23.80995

# %%
# Car with maximum consumption

vehicles_df[vehicles_df["Combined Km/L"] == np.min(vehicles_df["Combined Km/L"])]
# Out:
#               Make     Model  Year  Engine Displacement  Cylinders  \
# 20894  Lamborghini  Countach  1986                  5.2       12.0
# 20895  Lamborghini  Countach  1987                  5.2       12.0
# 20896  Lamborghini  Countach  1988                  5.2       12.0
# 20897  Lamborghini  Countach  1989                  5.2       12.0
# 20898  Lamborghini  Countach  1990                  5.2       12.0
#
#       Transmission        Drivetrain Vehicle Class Fuel Type  \
# 20894       manual  Rear-Wheel Drive   Two Seaters   Premium
# 20895       manual  Rear-Wheel Drive   Two Seaters   Premium
# 20896       manual  Rear-Wheel Drive   Two Seaters   Premium
# 20897       manual  Rear-Wheel Drive   Two Seaters   Premium
# 20898       manual  Rear-Wheel Drive   Two Seaters   Premium
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 20894          47.087143         6           10             7
# 20895          47.087143         6           10             7
# 20896          47.087143         6           10             7
# 20897          47.087143         6           10             7
# 20898          47.087143         6           10             7
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year  CO2 Emission Grams/Km  \
# 20894              1269.571429            5800             788.877073
# 20895              1269.571429            5800             788.877073
# 20896              1269.571429            5800             788.877073
# 20897              1269.571429            5800             788.877073
# 20898              1269.571429            5800             788.877073
#
#        City Km/L  Highway Km/L  Combined Km/L
# 20894   2.551066      4.251777       2.976244
# 20895   2.551066      4.251777       2.976244
# 20896   2.551066      4.251777       2.976244
# 20897   2.551066      4.251777       2.976244
# 20898   2.551066      4.251777       2.976244

# %% [markdown]
# #### What's the frequency of different transmissions, drivetrains and fuel types?

# %%
vehicles_df["Transmission"].value_counts()
# Out:
# automatic    24290
# manual       11662
# Name: Transmission, dtype: int64

# %%
n_total = len(vehicles_df)
n_total
# Out:
# 35952

# %%
n_manual = np.where(vehicles_df["Transmission"] == "manual", 1, 0).sum()
n_auto = np.where(vehicles_df["Transmission"] == "automatic", 1, 0).sum()

# %%
freq_manual = round(n_manual / n_total*100,2)
freq_auto = round(n_auto / n_total*100,2)
print(freq_manual)
print(freq_auto)
# Out:
# 32.44
# 67.56

# %%
vehicles_df["Drivetrain"].value_counts()
# Out:
# Front-Wheel Drive             13044
# Rear-Wheel Drive              12726
# 4-Wheel or All-Wheel Drive     6503
# All-Wheel Drive                2039
# 4-Wheel Drive                  1058
# 2-Wheel Drive                   423
# Part-time 4-Wheel Drive         158
# 2-Wheel Drive, Front              1
# Name: Drivetrain, dtype: int64

# %%
def frequency_calculator(df):
    
    output_dict = {}
    counts_df = pd.DataFrame(df.value_counts())
    n_total = len(df)
    
    for index in counts_df.index:
        
        n_index = np.where(df == index, 1, 0).sum()
        index_freq = round(n_index / n_total*100, 1)
        output_dict[index] = index_freq
        
    return output_dict

# %%
frequency_calculator(vehicles_df["Drivetrain"])
# Out:
# {'Front-Wheel Drive': 36.3,
#  'Rear-Wheel Drive': 35.4,
#  '4-Wheel or All-Wheel Drive': 18.1,
#  'All-Wheel Drive': 5.7,
#  '4-Wheel Drive': 2.9,
#  '2-Wheel Drive': 1.2,
#  'Part-time 4-Wheel Drive': 0.4,
#  '2-Wheel Drive, Front': 0.0}

# %% [markdown]
# What brand has the worse CO2 Emissions on average?
#
# Hint: use the function `sort_values()`

# %%
(vehicles_df[["Make","CO2 Emission Grams/Km"]].groupby(["Make"])
                                             .mean()
                                             .sort_values(by="CO2 Emission Grams/Km", ascending=False)
)
# Out:
#                                   CO2 Emission Grams/Km
# Make
# Vector                                       651.919248
# Bugatti                                      542.497235
# Laforza Automobile Inc                       502.012683
# Dutton                                       476.419879
# Rolls-Royce                                  475.397772
# Lamborghini                                  469.001266
# Texas Coach Company                          460.178293
# Maybach                                      453.327003
# Ferrari                                      442.812798
# Bentley                                      426.290692
# Ruf Automobile Gmbh                          424.779962
# Tecstar, LP                                  424.779962
# Aston Martin                                 417.946348
# Pagani                                       416.941106
# Saleen Performance                           409.609249
# Wallace Environmental                        408.857065
# Vixen Motor Company                          395.348404
# Excalibur Autos                              394.438536
# PAS, Inc                                     394.438536
# J.K. Motors                                  390.994816
# Roush Performance                            386.441107
# Maserati                                     385.686226
# AM General                                   379.881345
# SRT                                          377.173251
# Land Rover                                   373.280395
# Saleen                                       370.923931
# JBA Motorcars, Inc.                          368.142634
# PAS Inc - GMC                                368.142634
# Panos                                        368.142634
# CCC Engineering                              368.142634
# Aurora Cars Ltd                              368.142634
# Hummer                                       365.374644
# Spyker                                       361.479419
# Federal Coach                                360.588086
# Import Trade Services                        356.214289
# GMC                                          355.109034
# VPG                                          355.006336
# Bitter Gmbh and Co. Kg                       352.803358
# BMW Alpina                                   352.803358
# Environmental Rsch and Devp Corp             345.133719
# London Coach Co Inc                          345.133719
# ASC Incorporated                             345.133719
# Dodge                                        344.554180
# CX Automotive                                343.312774
# Mobility Ventures LLC                        340.201573
# Dabryan Coach Builders Inc                   339.268702
# Autokraft Limited                            334.982728
# Bill Dovell Motor Car Company                324.831736
# Lambda Control Systems                       324.831736
# Morgan                                       324.831736
# Grumman Allied Industries                    324.831736
# Shelby                                       324.831736
# Ford                                         320.296589
# Chevrolet                                    318.564940
# Mahindra                                     316.278723
# American Motors Corporation                  314.264744
# Mercedes-Benz                                311.421545
# Jeep                                         309.928716
# Cadillac                                     308.375552
# Goldacre                                     306.785528
# General Motors                               306.785528
# TVR Engineering Ltd                          306.785528
# Jaguar                                       306.582116
# Merkur                                       305.387965
# Isuzu                                        305.229090
# Sterling                                     304.252727
# McLaren Automotive                           303.981385
# Lincoln                                      302.572997
# Ram                                          298.360841
# Peugeot                                      291.565042
# Evans Automobiles                            290.638922
# Import Foreign Auto Sales Inc                290.638922
# Volga Associated Automobile                  290.638922
# Genesis                                      288.405717
# Alfa Romeo                                   288.287195
# Porsche                                      288.199235
# London Taxi                                  287.526112
# Infiniti                                     286.982449
# BMW                                          284.262087
# Nissan                                       283.443767
# Mcevoy Motors                                280.950958
# Audi                                         280.087391
# Chrysler                                     277.609760
# Lotus                                        276.195577
# Isis Imports Ltd                             276.106976
# Saab                                         275.571531
# Lexus                                        275.240120
# Oldsmobile                                   273.849170
# Panther Car Company Limited                  272.819988
# Mercury                                      271.489475
# Pininfarina                                  270.822632
# Volvo                                        270.796572
# Toyota                                       270.791631
# Buick                                        269.963993
# Mitsubishi                                   268.105004
# Qvale                                        262.959024
# Consulier Industries Inc                     262.959024
# Quantum Technologies                         262.959024
# Acura                                        262.583000
# Mazda                                        261.798342
# Plymouth                                     259.018217
# Pontiac                                      257.513762
# Eagle                                        255.476174
# Subaru                                       251.230978
# Bertone                                      251.006341
# Panoz Auto-Development                       251.006341
# Suzuki                                       244.042612
# Volkswagen                                   244.038998
# Kia                                          242.732303
# Daewoo                                       240.941937
# Dacia                                        240.093022
# Red Shift Ltd.                               240.093022
# Hyundai                                      239.241983
# Saturn                                       233.832051
# Renault                                      223.586374
# Honda                                        222.160996
# Grumman Olson                                221.418360
# Yugo                                         221.251107
# Geo                                          209.450825
# Scion                                        205.920389
# MINI                                         194.935105
# Daihatsu                                     192.742404
# Fiat                                         189.311494
# smart                                        153.498052
# Fisker                                       105.011992

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission on average?

# %%
(vehicles_df[["Transmission","CO2 Emission Grams/Km"]].groupby(["Transmission"])
                                             .mean()
                                             .sort_values(by="CO2 Emission Grams/Km", ascending=False)
)
# Out:
#               CO2 Emission Grams/Km
# Transmission
# automatic                302.853002
# manual                   279.718227
